# %%
from dcat_ap_hub import Dataset

# url = "http://localhost:8081/datasets/ba578d9a-2f7d-42b7-b7a8-a404a64979ec.jsonld"
# url = "http://localhost:8081/datasets/96d4eca1-4e85-4e46-895d-b84577b31398.jsonld"
url = "http://localhost:8081/datasets/b4286742-f993-4ec7-b869-109e98f00a58.jsonld"


ds = Dataset.from_url(url)
ds.download(data_dir="./data")
files = ds.process(processed_dir="./processed")
# Out:
# 2026-02-18 16:17:28,748 - dcat-ap-hub - INFO - Downloading: Dataset Archive (ZIP)
# Dataset Archive ZIP.zip: 100%|██████████| 32.7k/32.7k [00:00<00:00, 1.35MB/s]
# 2026-02-18 16:17:29,469 - dcat-ap-hub - INFO - [extract] Extracted Dataset Archive ZIP.zip
# 2026-02-18 16:17:29,470 - dcat-ap-hub - INFO - Downloading: Processor: IoT Predictive Maintenance
# processor_pmd.py: 6.28kB [00:00, 6.80MB/s]
# 2026-02-18 16:17:29,711 - dcat-ap-hub - INFO - Downloading: Notebook: IoT Predictive Maintenance
# notebook_pmd.ipynb: 562B [00:00, 1.09MB/s]
# Saving metadata for offline usage...
# Loading processor module: processor_pmd.py
# Found processor class: ProcessorPMD
# Processing 1 files...
# Success! Output saved to: data/IoT Integrated Predictive Maintenance Dataset/processed
